# %%
import pandas as pd
import glob

# %%
files=glob.glob("E:/tennis/*.csv")

# %%
dfs=[pd.read_csv(f) for f in files]
dfs
# Out:
# [     tourney_id   tourney_name surface  draw_size tourney_level indoor  \
#  0     1968-9346    Cape Town-1    Hard         64             A      O
#  1     1968-9346    Cape Town-1    Hard         64             A      O
#  2     1968-9346    Cape Town-1    Hard         64             A      O
#  3     1968-9346    Cape Town-1    Hard         64             A      O
#  4     1968-9346    Cape Town-1    Hard         64             A      O
#  ...         ...            ...     ...        ...           ...    ...
#  3718  1968-9278  New Orleans-2  Carpet         16             A      I
#  3719  1968-9278  New Orleans-2  Carpet         16             A      I
#  3720  1968-9278  New Orleans-2  Carpet         16             A      I
#  3721  1968-9278  New Orleans-2  Carpet         16             A      I
#  3722  1968-9278  New Orleans-2  Carpet         16             A      I
#
#        tourney_date  match_num winner_id  winner_seed  ...  w_bpFaced l_ace  \
# ...

# %%
df=pd.concat(dfs)
df.shape
# Out:
# (198063, 50)

# %%
data=df[df['tourney_date']>=19900101]
data.to_csv('1990_to_2026.csv')

# %%
# df.to_csv('CSV_TILL_1968_TO_2026.csv')
